# %% [markdown]
# <a href="https://colab.research.google.com/github/25f3005014-crypto/spam-classifier-ml/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample dataset
hours = np.array([1, 2, 3, 4, 5, 6, 7, 8]).reshape(-1,1)
scores = np.array([30, 40, 50, 60, 70, 80, 85, 95])

# Train model
model = LinearRegression()
model.fit(hours, scores)

# Predict
predicted_score = model.predict([[9]])
print("Predicted score for 9 hours:", predicted_score[0])

# Plot graph
plt.scatter(hours, scores)
plt.plot(hours, model.predict(hours))
plt.xlabel("Study Hours")
plt.ylabel("Score")
plt.title("Study Hours vs Score")
plt.show()
# Out:
# Predicted score for 9 hours: 105.5357142857143
