# %% [markdown]
# <a href="https://colab.research.google.com/github/25f3005014-crypto/spam-classifier-ml/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Load dataset
df = pd.read_csv(
    "https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv",
    sep="\t",
    names=["label", "message"]
)
# Convert labels to numbers
df["label"] = df["label"].map({"ham": 0, "spam": 1})

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    df["message"], df["label"], test_size=0.2, random_state=42
)

# Convert text to numbers
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train model
model = MultinomialNB()
model.fit(X_train_vec, y_train)

# Predict
y_pred = model.predict(X_test_vec)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Test custom message
msg = ["Congratulations! You won a free lottery ticket"]
msg = ["Congratulations! You won a free lottery worth 1 lakh"]
msg_vec = vectorizer.transform(msg)
print("Spam" if model.predict(msg_vec)[0] == 1 else "Not Spam")
print("\n\n\nSample Predictions:")
for i in range(5):
    print(X_test.iloc[i], "->", "Spam" if y_pred[i]==1 else "Not Spam")
# Out:
# Accuracy: 0.9668161434977578
# Spam
#
#
#
# Sample Predictions:
# Squeeeeeze!! This is christmas hug.. If u lik my frndshp den hug me back.. If u get 3 u r cute:) 6 u r luvd:* 9 u r so lucky;) None? People hate u: -> Not Spam
# And also I've sorta blown him off a couple times recently so id rather not text him out of the blue looking for weed -> Not Spam
# Mmm thats better now i got a roast down me! id b better if i had a few drinks down me 2! Good indian? -> Not Spam
# Mm have some kanji dont eat anything heavy ok -> Not Spam
# So there's a ring that comes with the guys costumes. It's there so they can gift their future yowifes. Hint hint -> Not Spam
